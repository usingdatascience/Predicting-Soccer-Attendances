# %% [markdown]
# ## Soccer Analytics - Predicting the attendances of English soccer matches
# This notebook utilises a dataset of English League 1 & 2 matches, from the 2017/18 season. The dataset was created by via a series of scripts (python + R) written by myself.
#
# The code for these scripts can be found in my github repo :-
# https://github.com/usingdatascience/Predicting-Soccer-Attendances.
#
# The dataset file has the following features :-
# * Date : date of match HomeTeam
# *  Home Team AwayTeam
# * Away Team Day_Eve : Is game a day or evening match ?
# * Day Type : Is the game on a weekend or during week ?
# * Holiday : Is the game played on a bank holiday ?
# * Hol Type : Same as Holiday
# * Capacity : Capacity of home teams ground
# * Average Travelling Fans : Average number of travelling fans that away team takes (based on previous season)
# * Cheapest Season T : Lowest Season ticket price for home team
# * Home League Position : Current position at time of game, of home team
# * Away League Position : Current position at time of game, of away team
# * Form Home : Current form of the home team (based on last 5 matches)
# * Form Away : Current form of the away team (based on last 5 matches)
# * Distance : Distance between the home sides ground and the away team
# * Temperature : Temperature on day of game Weather Event : ??
# * Lowest Home Ticket Price : Lowest ticket price for a home fan
# * Lowest Away Ticket Price : Lowest ticket price for an away fan
# * Home PostCode : Postcode of home team
# * Away PostCode : Postcode of away team
# * Attendance : Attendance for the game
# * Highest Home Ticket Price : Highest home ticket price that a fan can pay
#
# This notebook is the first attempt at Multiple Linear Regression on this dataset.

# %%
# Load library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
import statsmodels.api as sm
# Out:
# /Users/chappers/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# Load the dataset
df = pd.read_csv("final_dataset_V2copy.csv")
df.head()
# Out:
#    Unnamed: 0        Date      HomeTeam                AwayTeam Day_Eve  \
# 0           0  2016-08-05        Fulham               Newcastle       E
# 1           1  2016-08-06    Birmingham                 Cardiff       D
# 2           2  2016-08-06     Blackburn            Norwich City       D
# 3           3  2016-08-06  Bristol City          Wigan Athletic       D
# 4           4  2016-08-06         Derby  Brighton & Hove Albion       D
#
#    Day_Type  Hol_Type  Capacity  Average_Travelling_Fans  Cheapest_Season_T  \
# 0         1         0     25700                     3140              254.0
# 1         0         0     30016                      775              230.0
# 2         0         0     31367                     1661              279.0
# 3         0         0     21497                     1284              299.0
# 4         0         0     33597                     1611              319.0
#
#       ...       Away_League_Position  Form_Home  Form_Away  Distance  \
# 0     ...                          0          0          0     249.0
# 1     ...                          0          0          0      89.0
# 2     ...                          0          0          0     175.0
# 3     ...                          0          0          0     145.0
# 4     ...                          0          0          0     154.0
#
#    Temperature  Lowest_Home_Ticket_Price  Lowest_Away_Ticket_Price  \
# 0         20.2                      25.0                      24.0
# 1         18.8                      15.0                      22.0
# 2         17.9                      18.0                      20.0
# 3         19.1                      25.0                      20.0
# 4         19.3                      17.6                      25.0
#
#    Attendance  Highest_Home_Ticket_Price  match_month
# 0       23922                       45.0            8
# 1       19833                       40.0            8
# 2       12641                       35.0            8
# 3       17635                       41.0            8
# 4       28749                       33.0            8
#
# [5 rows x 21 columns]

# %%
df_sub = df[['HomeTeam','AwayTeam','Day_Eve','Hol_Type','Day_Type','Capacity','Average_Travelling_Fans','Cheapest_Season_T',
             'Home_League_Position','Away_League_Position','Form_Home','Form_Away','Distance','Temperature','Lowest_Home_Ticket_Price',
             'Lowest_Away_Ticket_Price','Highest_Home_Ticket_Price','match_month','Attendance']]
df_sub.iloc[30,:]
# Out:
# HomeTeam                     Preston
# AwayTeam                       Derby
# Day_Eve                            E
# Hol_Type                           0
# Day_Type                           1
# Capacity                       24500
# Average_Travelling_Fans         2137
# Cheapest_Season_T                360
# Home_League_Position              21
# Away_League_Position              17
# Form_Home                          0
# Form_Away                          1
# Distance                          79
# Temperature                     18.7
# Lowest_Home_Ticket_Price          24
# Lowest_Away_Ticket_Price        17.6
# Highest_Home_Ticket_Price         30
# match_month                        8
# Attendance                     10628
# Name: 30, dtype: object

# %%
# convert the teams columns to numbers using label decoding
df_sub['HTeam']=df_sub['HomeTeam'].astype('category')
df_sub["HTeam"] = df_sub["HTeam"].cat.codes
df_sub['ATeam']=df_sub['AwayTeam'].astype('category')
df_sub["ATeam"] = df_sub["ATeam"].cat.codes
df_sub["DayEve"] = df_sub["Day_Eve"].astype('category')
df_sub["DayEve"] = df_sub["DayEve"].cat.codes
df_sub.head()
# Out:
# /Users/chappers/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/chappers/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        HomeTeam                AwayTeam Day_Eve  Hol_Type  Day_Type  Capacity  \
# 0        Fulham               Newcastle       E         0         1     25700
# 1    Birmingham                 Cardiff       D         0         0     30016
# 2     Blackburn            Norwich City       D         0         0     31367
# 3  Bristol City          Wigan Athletic       D         0         0     21497
# 4         Derby  Brighton & Hove Albion       D         0         0     33597
#
#    Average_Travelling_Fans  Cheapest_Season_T  Home_League_Position  \
# 0                     3140              254.0                     0
# 1                      775              230.0                     0
# 2                     1661              279.0                     0
# 3                     1284              299.0                     0
# 4                     1611              319.0                     0
#
#    Away_League_Position   ...    Distance  Temperature  \
# 0                     0   ...       249.0         20.2
# 1                     0   ...        89.0         18.8
# 2                     0   ...       175.0         17.9
# 3                     0   ...       145.0         19.1
# 4                     0   ...       154.0         19.3
#
#    Lowest_Home_Ticket_Price  Lowest_Away_Ticket_Price  \
# 0                      25.0                      24.0
# 1                      15.0                      22.0
# 2                      18.0                      20.0
# 3                      25.0                      20.0
# 4                      17.6                      25.0
#
#    Highest_Home_Ticket_Price  match_month  Attendance  HTeam  ATeam  DayEve
# 0                       45.0            8       23922     19     26       1
# 1                       40.0            8       19833      3     13       0
# 2                       35.0            8       12641      4     28       0
# 3                       41.0            8       17635      9     46       0
# 4                       33.0            8       28749     17      8       0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Encoding of Categorical Variables :- HomeTeam + AwayTeam

# %%
# show the encoded values/mappings
htcodes = df_sub[['HomeTeam','HTeam']]
htcodes = htcodes.drop_duplicates(['HomeTeam','HTeam'])
htcodes
# Out:
#                    HomeTeam  HTeam
# 0                    Fulham     19
# 1                Birmingham      3
# 2                 Blackburn      4
# 3              Bristol City      9
# 4                     Derby     17
# 5              Huddersfield     21
# 6                   Ipswich     22
# 7              Nottm Forest     29
# 8                   Reading     36
# 9                 Rotherham     38
# 10                      QPR     35
# 11      Sheffield Wednesday     41
# 12   Brighton & Hove Albion      8
# 13              Aston Villa      1
# 14                 Barnsley      2
# 15                Brentford      7
# 16            Burton Albion     11
# 17             Leeds United     23
# 18                Newcastle     26
# 19             Norwich City     28
# 20                  Preston     34
# 21           Wigan Athletic     46
# 22                   Wolves     47
# 23                  Cardiff     13
# 552                  Bolton      5
# 553                Bradford      6
# 554                    Bury     12
# 555                Millwall     24
# 556             Northampton     27
# 557                  Oxford     31
# 558                Rochdale     37
# 559              Scunthorpe     39
# 560              Shrewsbury     42
# 561                Southend     43
# 562                 Swindon     44
# 563                 Walsall     45
# 564           AFC Wimbledon      0
# 565                Charlton     14
# 566            Chesterfield     15
# 567                Coventry     16
# 568          Fleetwood Town     18
# 569              Gillingham     20
# 570      Milton Keynes Dons     25
# 571                  Oldham     30
# 572               Peterboro     32
# 573               Port Vale     33
# 574        Sheffield United     40
# 575             Bristol Rvs     10

# %%
# show the encoded values/mappings
atcodes = df_sub[['AwayTeam','ATeam']]
atcodes = atcodes.drop_duplicates(['AwayTeam','ATeam'])
atcodes
# Out:
#                    AwayTeam  ATeam
# 0                 Newcastle     26
# 1                   Cardiff     13
# 2              Norwich City     28
# 3            Wigan Athletic     46
# 4    Brighton & Hove Albion      8
# 5                 Brentford      7
# 6                  Barnsley      2
# 7             Burton Albion     11
# 8                   Preston     34
# 9                    Wolves     47
# 10             Leeds United     23
# 11              Aston Villa      1
# 12             Nottm Forest     29
# 13                Rotherham     38
# 14                    Derby     17
# 15                  Ipswich     22
# 16             Bristol City      9
# 17               Birmingham      3
# 18             Huddersfield     21
# 19      Sheffield Wednesday     41
# 20                   Fulham     19
# 21                Blackburn      4
# 22                  Reading     36
# 23                      QPR     35
# 552        Sheffield United     40
# 553               Port Vale     33
# 554                Charlton     14
# 555                  Oldham     30
# 556          Fleetwood Town     18
# 557            Chesterfield     15
# 558               Peterboro     32
# 559             Bristol Rvs     10
# 560      Milton Keynes Dons     25
# 561              Gillingham     20
# 562                Coventry     16
# 563           AFC Wimbledon      0
# 564                  Bolton      5
# 565             Northampton     27
# 566                 Swindon     44
# 567              Shrewsbury     42
# 568              Scunthorpe     39
# 569                    Bury     12
# 570                Millwall     24
# 571                 Walsall     45
# 572                Bradford      6
# 573                Southend     43
# 574                Rochdale     37
# 575                  Oxford     31

# %%
# show the encoded values/mappings
dayeve_codes = df_sub[['Day_Eve','DayEve']]
dayeve_codes = dayeve_codes.drop_duplicates(['Day_Eve','DayEve'])
dayeve_codes
# Out:
#   Day_Eve  DayEve
# 0       E       1
# 1       D       0

# %%
# drop the original home and away team columns
df_sub = df_sub[['HTeam','ATeam','DayEve','Hol_Type','Day_Type','Capacity','Average_Travelling_Fans','Cheapest_Season_T',
             'Home_League_Position','Away_League_Position','Form_Home','Form_Away','Distance','Temperature','Lowest_Home_Ticket_Price',
             'Lowest_Away_Ticket_Price','Highest_Home_Ticket_Price','match_month','Attendance']]
df_sub.head()
# Out:
#    HTeam  ATeam  DayEve  Hol_Type  Day_Type  Capacity  \
# 0     19     26       1         0         1     25700
# 1      3     13       0         0         0     30016
# 2      4     28       0         0         0     31367
# 3      9     46       0         0         0     21497
# 4     17      8       0         0         0     33597
#
#    Average_Travelling_Fans  Cheapest_Season_T  Home_League_Position  \
# 0                     3140              254.0                     0
# 1                      775              230.0                     0
# 2                     1661              279.0                     0
# 3                     1284              299.0                     0
# 4                     1611              319.0                     0
#
#    Away_League_Position  Form_Home  Form_Away  Distance  Temperature  \
# 0                     0          0          0     249.0         20.2
# 1                     0          0          0      89.0         18.8
# 2                     0          0          0     175.0         17.9
# 3                     0          0          0     145.0         19.1
# 4                     0          0          0     154.0         19.3
#
#    Lowest_Home_Ticket_Price  Lowest_Away_Ticket_Price  \
# 0                      25.0                      24.0
# 1                      15.0                      22.0
# 2                      18.0                      20.0
# 3                      25.0                      20.0
# 4                      17.6                      25.0
#
#    Highest_Home_Ticket_Price  match_month  Attendance
# 0                       45.0            8       23922
# 1                       40.0            8       19833
# 2                       35.0            8       12641
# 3                       41.0            8       17635
# 4                       33.0            8       28749

# %%
X = np.array(df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position','Away_League_Position',
       'Form_Home','Form_Away','Distance','Temperature','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','HTeam','ATeam']])
y = df_sub.Attendance

# %% [markdown]
# ### Checking for Multicollinearity
# This is the presence of correlation in independant variables.  If variables are correlated, then it becomes extremely difficult for the model to determine the true effect of X on Y or find out which variable is contributing to predict the response variable. To investigate if any variables are correlated, then produce a Correlation Table. (nb. scatter plots could also be done).

# %%
correlationMatrix = df_sub.corr().abs()

plt.subplots(figsize=(18, 8))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %% [markdown]
# Attendance is the Response Variable, so we can ignore any correlations here. On the other variables, its only Capacity and "Highest Home Ticket Price" that seem to be exhibiting a correlation.
#
# Before modelling the data via regression, as the data items have different scales (ie. some have values of 0 or 1, some in the hundreds, some in the thousands), we therefore scale all of the X variables.

# %%
# Scale the features: X_scaled
X_scaled = scale(X)
X_scaled
# Out:
# array([[ 1.40276225, -0.28881675,  1.40276225, ...,  0.40101496,
#         -0.32483003,  0.18046113],
#        [-0.71287918, -0.28881675, -0.71287918, ...,  0.40101496,
#         -1.47978123, -0.75793673],
#        [-0.71287918, -0.28881675, -0.71287918, ...,  0.40101496,
#         -1.40759678,  0.32483003],
#        ...,
#        [-0.71287918, -0.28881675, -0.71287918, ..., -0.64068037,
#          1.19104343, -0.61356783],
#        [-0.71287918, -0.28881675, -0.71287918, ..., -0.64068037,
#          1.40759678, -0.83012118],
#        [-0.71287918, -0.28881675, -0.71287918, ..., -0.64068037,
#          1.55196568,  0.10827668]])

# %%
# Print the mean and standard deviation of the unscaled features
print("Mean of Unscaled Features: {}".format(np.mean(X))) 
print("Standard Deviation of Unscaled Features: {}".format(np.std(X)))

# Print the mean and standard deviation of the scaled features
print("Mean of Scaled Features: {}".format(np.mean(X_scaled))) 
print("Standard Deviation of Scaled Features: {}".format(np.std(X_scaled)))
# Out:
# Mean of Unscaled Features: 1315.0496390901772
# Standard Deviation of Unscaled Features: 5611.48051281267
# Mean of Scaled Features: -8.581434006764495e-17
# Standard Deviation of Scaled Features: 1.0

# %%
# Create training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.3, random_state=42)

# Create the regressor: reg_all
reg_all = LinearRegression()

# %%
# Fit the regressor to the training data
reg_all.fit(X_train,y_train)

# Predict on the test data: y_pred
y_pred = reg_all.predict(X_test)

# Compute and print R^2 and RMSE
print("R^2: {}".format(reg_all.score(X_test, y_test)))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error: {}".format(rmse))
# Out:
# R^2: 0.7977412964519359
# Root Mean Squared Error: 4162.34424120285

# %% [markdown]
# ### Model Evaluation Metrics for Regression
# MAE = Mean Absolute Error
# MSE = Mean Squared Error
# RMSE = Root Mean Squared Error
#
# Comparing these metrics:
#
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
#
# Mean Squared Error (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
#
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$

# %%
# calculate MAE using scikit-learn
from sklearn import metrics
print(metrics.mean_absolute_error(y_test, y_pred))
# Out:
# 3263.96385542

# %%
# calculate MSE using scikit-learn
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 17325109.5823

# %%
# calculate RMSE using scikit-learn
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 4162.3442412

# %%
import matplotlib.pyplot as plt

# regression coefficients
print('Coefficients: \n', reg_all.coef_)
 
# variance score: 1 means perfect prediction
print('Variance score: {}'.format(reg_all.score(X_test, y_test)))
 
# plot for residual error
 
## setting plot style
plt.style.use('fivethirtyeight')
 
## plotting residual errors in training data
plt.scatter(reg_all.predict(X_train), reg_all.predict(X_train) - y_train,
            color = "green", s = 10, label = 'Train data')
 
## plotting residual errors in test data
plt.scatter(reg_all.predict(X_test), reg_all.predict(X_test) - y_test,
            color = "blue", s = 10, label = 'Test data')
 
## plotting line for zero residual error
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2)
 
## plotting legend
plt.legend(loc = 'upper right')
 
## plot title
plt.title("Residual errors")
 
## function to show plot
plt.show()
# Out:
# Coefficients:
#  [  1.95063290e+17   5.63205555e+02  -1.95063290e+17   6.73338021e+03
#    1.52796966e+03   1.36634389e+03  -1.72763291e+03  -1.59488621e+02
#    2.07838893e+02  -1.37152051e+02  -2.63456347e+02   2.75714282e+00
#    3.70031592e+01  -1.92667361e+02   7.20720981e+02  -3.13315854e+02
#   -3.19696454e+02  -2.56782766e+02]
# Variance score: 0.7977412964519359

# %% [markdown]
# ### Above plot suggests non-linearity in the data. It means that the model doesn’t capture nonlinear effects.  The funnel shape in the plot, indicates signs of non-constant variance i.e. heteroskedasticity.

# %%
residuals = y_test - y_pred
residuals.describe()
# Out:
# count      332.000000
# mean      -283.659701
# std       4158.935607
# min     -11910.268135
# 25%      -2771.768135
# 50%         -8.268135
# 75%       2384.481865
# max      13792.731865
# Name: Attendance, dtype: float64

# %%
import scipy.stats as stats
plt.figure(figsize=(9,9))
stats.probplot(residuals, dist="norm", plot=plt)
# Out:
# ((array([-2.86491366, -2.57155096, -2.40569144, -2.28762493, -2.19481524,
#          -2.11777256, -2.05156645, -1.9932937 , -1.94109482, -1.89370439,
#          -1.85022076, -1.80997787, -1.77246922, -1.73730029, -1.70415753,
#          -1.67278747, -1.64298217, -1.61456881, -1.58740219, -1.56135902,
#          -1.53633375, -1.51223525, -1.48898428, -1.46651151, -1.44475587,
#          -1.42366334, -1.40318583, -1.38328038, -1.36390841, -1.34503518,
#          -1.32662925, -1.3086621 , -1.29110775, -1.2739425 , -1.25714461,
#          -1.24069415, -1.22457275, -1.2087635 , -1.19325071, -1.17801988,
#          -1.16305753, -1.14835112, -1.13388897, -1.11966017, -1.10565451,
#          -1.09186245, -1.07827501, -1.06488378, -1.05168083, -1.03865871,
#          -1.02581039, -1.0131292 , -1.00060889, -0.98824349, -0.97602739,
#          -0.96395523, -0.95202194, -0.94022271, -0.92855295, -0.91700829,
#          -0.90558457, -0.89427783, -0.88308428, -0.87200029, -0.86102241,
#          -0.85014733, -0.83937187, -0.82869301, -0.81810782, -0.80761351,
#          -0.79720741, -0.78688692, -0.77664957, -0.76649298, -0.75641485,
#          -0.74641297, -0.7364852 , -0.7266295 , -0.71684388, -0.70712643,
#          -0.6974753 , -0.6878887 , -0.67836491, -0.66890225, -0.65949911,
#          -0.65015393, -0.64086518, -0.63163141, -0.62245117, -0.6133231 ,
#          -0.60424585, -0.59521812, -0.58623863, -0.57730617, -0.56841954,
#          -0.55957757, -0.55077914, -0.54202314, -0.5333085 , -0.52463417,
#          -0.51599914, -0.50740242, -0.49884303, -0.49032004, -0.48183251,
#          -0.47337956, -0.46496029, -0.45657386, -0.44821941, -0.43989613,
#          -0.43160322, -0.42333989, -0.41510536, -0.40689888, -0.39871971,
#          -0.39056714, -0.38244044, -0.37433892, -0.36626189, -0.35820869,
#          -0.35017866, -0.34217114, -0.3341855 , -0.32622112, -0.31827737,
#          -0.31035366, -0.30244939, -0.29456397, -0.28669682, -0.27884738,
#          -0.27101508, -0.26319937, -0.25539971, -0.24761555, -0.23984637,
#          -0.23209164, -0.22435084, -0.21662346, -0.208909  , -0.20120695,
#          -0.19351681, -0.18583811, -0.17817034, -0.17051304, -0.16286572,
#          -0.15522791, -0.14759915, -0.13997897, -0.13236691, -0.12476251,
#          -0.11716532, -0.10957489, -0.10199076, -0.0944125 , -0.08683965,
#          -0.07927178, -0.07170845, -0.06414922, -0.05659365, -0.04904131,
#          -0.04149177, -0.03394459, -0.02639934, -0.0188556 , -0.01131293,
#            4.30073187e+03,   4.35173187e+03,   4.37973187e+03,
#            4.41173187e+03,   4.43473187e+03,   4.55273187e+03,
#            4.57073187e+03,   4.58173187e+03,   4.66273187e+03,
#            4.72773187e+03,   4.76773187e+03,   4.77173187e+03,
#            4.79573187e+03,   4.85073187e+03,   4.94473187e+03,
#            4.94673187e+03,   5.08573187e+03,   5.12873187e+03,
#            5.40373187e+03,   5.47473187e+03,   5.55473187e+03,
#            5.79473187e+03,   6.04573187e+03,   6.26173187e+03,
#            6.37573187e+03,   6.68973187e+03,   7.38273187e+03,
#            7.88673187e+03,   8.18173187e+03,   8.96773187e+03,
#            9.63773187e+03,   1.27167319e+04,   1.27357319e+04,
#            1.28547319e+04,   1.37927319e+04])),
#  (4150.2226748441244, -283.65970098008773, 0.9921782190502525))

# %% [markdown]
# ### If residuals are normally distributed, then they should like along the straight line on the Q-Q plot. The residuals here appear to not fully follow the normality line. This is an indication that this model/straight line may not be sufficent to predict attendances.
#
#
# ### Now below try backwards elimination

# %%
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position','Away_League_Position',
       'Form_Home','Form_Away','Distance','Temperature','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','HTeam','ATeam']]
y = df_sub.Attendance

# %%
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2, fit_intercept=True).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     282.1
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:04   Log-Likelihood:                -10780.
# No. Observations:                1104   AIC:                         2.160e+04
# Df Residuals:                    1086   BIC:                         2.169e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -6036.1600   1249.660     -4.830      0.000   -8488.181   -3584.139
# Day_Type                   -717.8696    148.865     -4.822      0.000   -1009.964    -425.775
# Hol_Type                   2479.3415    527.935      4.696      0.000    1443.454    3515.229
# DayEve                     -717.8696    148.865     -4.822      0.000   -1009.964    -425.775
# Capacity                      0.6117      0.016     38.057      0.000       0.580       0.643
# Average_Travelling_Fans       2.2202      0.222      9.985      0.000       1.784       2.656
# Cheapest_Season_T            18.1389      2.119      8.560      0.000      13.981      22.297
# Home_League_Position       -237.2246     22.418    -10.582      0.000    -281.212    -193.237
# Away_League_Position         -8.5041     22.563     -0.377      0.706     -52.775      35.767
# Form_Home                    96.6919     43.788      2.208      0.027      10.772     182.611
# Form_Away                    15.2998     44.019      0.348      0.728     -71.073     101.672
# Distance                     -4.2881      2.309     -1.857      0.064      -8.819       0.243
# Temperature                  -5.6846     26.929     -0.211      0.833     -58.523      47.154
# Lowest_Home_Ticket_Price     15.5835     38.610      0.404      0.687     -60.174      91.341
# Lowest_Away_Ticket_Price    -39.3626     33.623     -1.171      0.242    -105.336      26.610
# Highest_Home_Ticket_Price   109.4793     29.908      3.661      0.000      50.795     168.164
# match_month                 -56.5638     34.412     -1.644      0.101    -124.086      10.958
# HTeam                       -26.4906     10.551     -2.511      0.012     -47.194      -5.788
# ATeam                       -13.0462      9.411     -1.386      0.166     -31.512       5.419
# ==============================================================================
# Omnibus:                       41.507   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.371
# Skew:                           0.331   Prob(JB):                     1.73e-14
# Kurtosis:                       3.969   Cond. No.                     1.72e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.23e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove Temperature as greater than 0.05
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position','Away_League_Position',
       'Form_Home','Form_Away','Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','HTeam','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     300.0
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:05   Log-Likelihood:                -10780.
# No. Observations:                1104   AIC:                         2.159e+04
# Df Residuals:                    1087   BIC:                         2.168e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -6110.2068   1198.893     -5.097      0.000   -8462.614   -3757.800
# Day_Type                   -716.8463    148.720     -4.820      0.000   -1008.657    -425.035
# Hol_Type                   2488.8194    525.791      4.733      0.000    1457.140    3520.499
# DayEve                     -716.8463    148.720     -4.820      0.000   -1008.657    -425.035
# Capacity                      0.6119      0.016     38.126      0.000       0.580       0.643
# Average_Travelling_Fans       2.2200      0.222      9.989      0.000       1.784       2.656
# Cheapest_Season_T            18.1146      2.115      8.565      0.000      13.965      22.264
# Home_League_Position       -236.8695     22.345    -10.601      0.000    -280.713    -193.026
# Away_League_Position         -7.7215     22.246     -0.347      0.729     -51.372      35.929
# Form_Home                    98.3800     43.033      2.286      0.022      13.943     182.817
# Form_Away                    17.2705     42.999      0.402      0.688     -67.100     101.641
# Distance                     -4.3238      2.302     -1.878      0.061      -8.840       0.193
# Lowest_Home_Ticket_Price     15.6944     38.589      0.407      0.684     -60.023      91.412
# Lowest_Away_Ticket_Price    -39.4027     33.607     -1.172      0.241    -105.345      26.540
# Highest_Home_Ticket_Price   109.0812     29.835      3.656      0.000      50.540     167.623
# match_month                 -57.9412     33.773     -1.716      0.087    -124.209       8.326
# HTeam                       -26.4415     10.544     -2.508      0.012     -47.130      -5.753
# ATeam                       -13.0390      9.407     -1.386      0.166     -31.496       5.418
# ==============================================================================
# Omnibus:                       41.336   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.011
# Skew:                           0.331   Prob(JB):                     2.08e-14
# Kurtosis:                       3.965   Cond. No.                     4.55e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.18e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove away_league_position as greater than 0.05
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position',
       'Form_Home','Form_Away','Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','HTeam','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     320.3
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:07   Log-Likelihood:                -10780.
# No. Observations:                1104   AIC:                         2.159e+04
# Df Residuals:                    1088   BIC:                         2.167e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -6203.0330   1168.211     -5.310      0.000   -8495.235   -3910.831
# Day_Type                   -717.5960    148.644     -4.828      0.000   -1009.258    -425.934
# Hol_Type                   2485.0930    525.469      4.729      0.000    1454.046    3516.139
# DayEve                     -717.5960    148.644     -4.828      0.000   -1009.258    -425.934
# Capacity                      0.6119      0.016     38.146      0.000       0.580       0.643
# Average_Travelling_Fans       2.2313      0.220     10.154      0.000       1.800       2.662
# Cheapest_Season_T            18.1214      2.114      8.572      0.000      13.973      22.269
# Home_League_Position       -237.8876     22.143    -10.743      0.000    -281.335    -194.441
# Form_Home                    94.6811     41.676      2.272      0.023      12.907     176.455
# Form_Away                    25.1066     36.581      0.686      0.493     -46.670      96.883
# Distance                     -4.2783      2.297     -1.862      0.063      -8.786       0.229
# Lowest_Home_Ticket_Price     15.4389     38.566      0.400      0.689     -60.234      91.112
# Lowest_Away_Ticket_Price    -39.6184     33.588     -1.180      0.238    -105.523      26.286
# Highest_Home_Ticket_Price   108.1563     29.704      3.641      0.000      49.872     166.440
# match_month                 -57.4993     33.735     -1.704      0.089    -123.693       8.694
# HTeam                       -26.3897     10.539     -2.504      0.012     -47.068      -5.711
# ATeam                       -13.2169      9.389     -1.408      0.159     -31.639       5.205
# ==============================================================================
# Omnibus:                       41.143   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               62.470
# Skew:                           0.331   Prob(JB):                     2.72e-14
# Kurtosis:                       3.959   Cond. No.                     3.57e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.18e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove lowest_home_Ticket_price as greater than 0.05
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position',
       'Form_Home','Form_Away','Distance','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','HTeam','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     343.4
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:07   Log-Likelihood:                -10780.
# No. Observations:                1104   AIC:                         2.159e+04
# Df Residuals:                    1089   BIC:                         2.167e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -6629.6213    995.802     -6.658      0.000   -8583.525   -4675.717
# Day_Type                   -713.3367    148.502     -4.804      0.000   -1004.719    -421.955
# Hol_Type                   2487.7150    524.871      4.740      0.000    1457.844    3517.586
# DayEve                     -713.3367    148.502     -4.804      0.000   -1004.719    -421.955
# Capacity                      0.6107      0.016     38.164      0.000       0.579       0.642
# Average_Travelling_Fans       2.1917      0.207     10.586      0.000       1.786       2.598
# Cheapest_Season_T            18.2452      2.063      8.842      0.000      14.196      22.294
# Home_League_Position       -235.6666     21.832    -10.794      0.000    -278.505    -192.828
# Form_Home                    98.3197     40.645      2.419      0.016      18.568     178.071
# Distance                     -4.0655      2.289     -1.776      0.076      -8.556       0.425
# Highest_Home_Ticket_Price   111.8109     29.142      3.837      0.000      54.630     168.992
# match_month                 -59.8451     33.529     -1.785      0.075    -125.635       5.944
# HTeam                       -27.0501     10.325     -2.620      0.009     -47.308      -6.792
# ATeam                       -14.3957      9.334     -1.542      0.123     -32.710       3.918
# ==============================================================================
# Omnibus:                       41.574   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.261
# Skew:                           0.333   Prob(JB):                     1.83e-14
# Kurtosis:                       3.965   Cond. No.                     3.50e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.39e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove ATeam as greater than 0.05
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position',
       'Form_Home','Distance',
       'Highest_Home_Ticket_Price','match_month','HTeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     436.3
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:10   Log-Likelihood:                -10782.
# No. Observations:                1104   AIC:                         2.159e+04
# Df Residuals:                    1092   BIC:                         2.165e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -7106.4448    947.194     -7.503      0.000   -8964.971   -5247.918
# Day_Type                   -713.8053    148.595     -4.804      0.000   -1005.370    -422.241
# Hol_Type                   2484.6921    525.199      4.731      0.000    1454.179    3515.205
# DayEve                     -713.8053    148.595     -4.804      0.000   -1005.370    -422.241
# Capacity                      0.6109      0.016     38.155      0.000       0.579       0.642
# Average_Travelling_Fans       2.2252      0.206     10.801      0.000       1.821       2.629
# Cheapest_Season_T            18.2309      2.065      8.830      0.000      14.180      22.282
# Home_League_Position       -234.7252     21.838    -10.749      0.000    -277.574    -191.877
# Form_Home                    99.5497     40.663      2.448      0.015      19.764     179.336
# Distance                     -3.8736      2.287     -1.694      0.091      -8.360       0.613
# Highest_Home_Ticket_Price   113.1490     29.147      3.882      0.000      55.958     170.340
# match_month                 -59.6975     33.550     -1.779      0.075    -125.528       6.133
# HTeam                       -26.3448     10.321     -2.553      0.011     -46.596      -6.094
# ==============================================================================
# Omnibus:                       41.674   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               62.817
# Skew:                           0.337   Prob(JB):                     2.29e-14
# Kurtosis:                       3.955   Cond. No.                     1.20e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.6e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove distance as greater than 0.05
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position',
       'Form_Home','Highest_Home_Ticket_Price','match_month','HTeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     478.8
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:10   Log-Likelihood:                -10784.
# No. Observations:                1104   AIC:                         2.159e+04
# Df Residuals:                    1093   BIC:                         2.164e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -7509.2482    917.648     -8.183      0.000   -9309.799   -5708.697
# Day_Type                   -714.1977    148.722     -4.802      0.000   -1006.011    -422.384
# Hol_Type                   2546.3018    524.386      4.856      0.000    1517.385    3575.219
# DayEve                     -714.1977    148.722     -4.802      0.000   -1006.011    -422.384
# Capacity                      0.6125      0.016     38.294      0.000       0.581       0.644
# Average_Travelling_Fans       2.2373      0.206     10.856      0.000       1.833       2.642
# Cheapest_Season_T            17.8640      2.055      8.693      0.000      13.832      21.896
# Home_League_Position       -230.0361     21.680    -10.611      0.000    -272.575    -187.497
# Form_Home                   100.9162     40.690      2.480      0.013      21.078     180.755
# Highest_Home_Ticket_Price   110.8373     29.140      3.804      0.000      53.660     168.015
# match_month                 -54.7768     33.453     -1.637      0.102    -120.416      10.863
# HTeam                       -25.4016     10.315     -2.463      0.014     -45.640      -5.163
# ==============================================================================
# Omnibus:                       36.567   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.524
# Skew:                           0.317   Prob(JB):                     3.93e-12
# Kurtosis:                       3.860   Cond. No.                     1.50e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.94e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove match_month as greater than 0.05
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position',
       'Form_Home','Highest_Home_Ticket_Price','HTeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     530.9
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:11   Log-Likelihood:                -10785.
# No. Observations:                1104   AIC:                         2.159e+04
# Df Residuals:                    1094   BIC:                         2.164e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -7904.0231    886.090     -8.920      0.000   -9642.651   -6165.395
# Day_Type                   -698.7478    148.537     -4.704      0.000    -990.197    -407.299
# Hol_Type                   2567.2829    524.632      4.893      0.000    1537.884    3596.682
# DayEve                     -698.7478    148.537     -4.704      0.000    -990.197    -407.299
# Capacity                      0.6118      0.016     38.234      0.000       0.580       0.643
# Average_Travelling_Fans       2.2351      0.206     10.838      0.000       1.830       2.640
# Cheapest_Season_T            17.8246      2.056      8.667      0.000      13.789      21.860
# Home_League_Position       -228.5004     21.676    -10.541      0.000    -271.032    -185.968
# Form_Home                   102.4386     40.710      2.516      0.012      22.560     182.318
# Highest_Home_Ticket_Price   111.6865     29.158      3.830      0.000      54.474     168.899
# HTeam                       -25.2897     10.322     -2.450      0.014     -45.544      -5.036
# ==============================================================================
# Omnibus:                       35.686   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.732
# Skew:                           0.314   Prob(JB):                     9.63e-12
# Kurtosis:                       3.841   Cond. No.                     4.66e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.03e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# summarize our model
regOLS_model_summary = regressor_OLS.summary()
regOLS_model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     530.9
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:12   Log-Likelihood:                -10785.
# No. Observations:                1104   AIC:                         2.159e+04
# Df Residuals:                    1094   BIC:                         2.164e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -7904.0231    886.090     -8.920      0.000   -9642.651   -6165.395
# Day_Type                   -698.7478    148.537     -4.704      0.000    -990.197    -407.299
# Hol_Type                   2567.2829    524.632      4.893      0.000    1537.884    3596.682
# DayEve                     -698.7478    148.537     -4.704      0.000    -990.197    -407.299
# Capacity                      0.6118      0.016     38.234      0.000       0.580       0.643
# Average_Travelling_Fans       2.2351      0.206     10.838      0.000       1.830       2.640
# Cheapest_Season_T            17.8246      2.056      8.667      0.000      13.789      21.860
# Home_League_Position       -228.5004     21.676    -10.541      0.000    -271.032    -185.968
# Form_Home                   102.4386     40.710      2.516      0.012      22.560     182.318
# Highest_Home_Ticket_Price   111.6865     29.158      3.830      0.000      54.474     168.899
# HTeam                       -25.2897     10.322     -2.450      0.014     -45.544      -5.036
# ==============================================================================
# Omnibus:                       35.686   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.732
# Skew:                           0.314   Prob(JB):                     9.63e-12
# Kurtosis:                       3.841   Cond. No.                     4.66e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.03e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
fig = plt.figure(figsize=(20,24))
fig = sm.graphics.plot_partregress_grid(regressor_OLS, fig=fig)

# %%
# seaborn residual plot
sns.residplot(regressor_OLS.fittedvalues, df_sub['Attendance'], lowess=True, line_kws={'color':'r', 'lw':1})
plt.title('Residual plot')
plt.xlabel('Predicted values')
plt.ylabel('Residuals');

# %% [markdown]
# ### Above graph suggests non-linearity in the data.  If a funnel shape is evident in the plot, consider it as the signs of non-constant variance i.e. heteroskedasticity.  To rectify this, could try transforming Y, using ln, or Sqrt

# %%
fig, ax = plt.subplots(figsize=(24,16))
fig = sm.graphics.influence_plot(regressor_OLS, ax=ax, criterion="cooks")

# %% [markdown]
# ### The above plot shows up possible outliers. Anything greater than 3 is a possible outlier. Possible action is to remove these from the dataset.

# %%
# Q-Q plot for normality
figqq= sm.qqplot(regressor_OLS.resid, line='r')

# %% [markdown]
# ### This plot shows if residuals are normally distributed. Do residuals follow a straight line well or do they deviate severely? It’s good if residuals are lined well on the straight red line.

# %% [markdown]
# ### Now try backwards elimination, but with LOG(Y) used for Response variable Y

# %%
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position','Away_League_Position',
       'Form_Home','Form_Away','Distance','Temperature','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','HTeam','ATeam']]
y = np.log(y)
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     313.2
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:24   Log-Likelihood:                -204.33
# No. Observations:                1104   AIC:                             444.7
# Df Residuals:                    1086   BIC:                             534.8
# Df Model:                          17
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         7.6420      0.086     88.468      0.000       7.473       7.812
# Day_Type                     -0.0522      0.010     -5.069      0.000      -0.072      -0.032
# Hol_Type                      0.1622      0.036      4.445      0.000       0.091       0.234
# DayEve                       -0.0522      0.010     -5.069      0.000      -0.072      -0.032
# Capacity                   3.895e-05   1.11e-06     35.056      0.000    3.68e-05    4.11e-05
# Average_Travelling_Fans       0.0002   1.54e-05     10.949      0.000       0.000       0.000
# Cheapest_Season_T             0.0002      0.000      1.149      0.251      -0.000       0.000
# Home_League_Position         -0.0114      0.002     -7.364      0.000      -0.014      -0.008
# Away_League_Position         -0.0018      0.002     -1.148      0.251      -0.005       0.001
# Form_Home                     0.0049      0.003      1.629      0.104      -0.001       0.011
# Form_Away                     0.0007      0.003      0.223      0.823      -0.005       0.007
# Distance                     -0.0009      0.000     -5.541      0.000      -0.001      -0.001
# Temperature                   0.0002      0.002      0.099      0.921      -0.003       0.004
# Lowest_Home_Ticket_Price      0.0074      0.003      2.765      0.006       0.002       0.013
# Lowest_Away_Ticket_Price     -0.0061      0.002     -2.631      0.009      -0.011      -0.002
# Highest_Home_Ticket_Price     0.0273      0.002     13.194      0.000       0.023       0.031
# match_month                  -0.0038      0.002     -1.618      0.106      -0.009       0.001
# HTeam                        -0.0004      0.001     -0.585      0.559      -0.002       0.001
# ATeam                        -0.0012      0.001     -1.816      0.070      -0.002    9.49e-05
# ==============================================================================
# Omnibus:                       31.778   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.168
# Skew:                          -0.169   Prob(JB):                     6.88e-05
# Kurtosis:                       2.450   Cond. No.                     1.72e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.23e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove temperature variable
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position','Away_League_Position',
       'Form_Home','Form_Away','Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','HTeam','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     333.1
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:25   Log-Likelihood:                -204.33
# No. Observations:                1104   AIC:                             442.7
# Df Residuals:                    1087   BIC:                             527.8
# Df Model:                          16
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         7.6444      0.083     92.244      0.000       7.482       7.807
# Day_Type                     -0.0522      0.010     -5.077      0.000      -0.072      -0.032
# Hol_Type                      0.1619      0.036      4.455      0.000       0.091       0.233
# DayEve                       -0.0522      0.010     -5.077      0.000      -0.072      -0.032
# Capacity                   3.895e-05   1.11e-06     35.107      0.000    3.68e-05    4.11e-05
# Average_Travelling_Fans       0.0002   1.54e-05     10.955      0.000       0.000       0.000
# Cheapest_Season_T             0.0002      0.000      1.156      0.248      -0.000       0.000
# Home_League_Position         -0.0114      0.002     -7.396      0.000      -0.014      -0.008
# Away_League_Position         -0.0018      0.002     -1.181      0.238      -0.005       0.001
# Form_Home                     0.0049      0.003      1.639      0.101      -0.001       0.011
# Form_Away                     0.0006      0.003      0.207      0.836      -0.005       0.006
# Distance                     -0.0009      0.000     -5.551      0.000      -0.001      -0.001
# Lowest_Home_Ticket_Price      0.0074      0.003      2.765      0.006       0.002       0.013
# Lowest_Away_Ticket_Price     -0.0061      0.002     -2.632      0.009      -0.011      -0.002
# Highest_Home_Ticket_Price     0.0273      0.002     13.233      0.000       0.023       0.031
# match_month                  -0.0038      0.002     -1.629      0.104      -0.008       0.001
# HTeam                        -0.0004      0.001     -0.587      0.557      -0.002       0.001
# ATeam                        -0.0012      0.001     -1.817      0.069      -0.002    9.41e-05
# ==============================================================================
# Omnibus:                       31.719   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.177
# Skew:                          -0.170   Prob(JB):                     6.85e-05
# Kurtosis:                       2.451   Cond. No.                     4.55e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.18e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove form_away variable
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position','Away_League_Position',
       'Form_Home','Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','HTeam','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     355.6
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:26   Log-Likelihood:                -204.35
# No. Observations:                1104   AIC:                             440.7
# Df Residuals:                    1088   BIC:                             520.8
# Df Model:                          15
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         7.6472      0.082     93.564      0.000       7.487       7.808
# Day_Type                     -0.0521      0.010     -5.075      0.000      -0.072      -0.032
# Hol_Type                      0.1622      0.036      4.467      0.000       0.091       0.233
# DayEve                       -0.0521      0.010     -5.075      0.000      -0.072      -0.032
# Capacity                   3.894e-05   1.11e-06     35.123      0.000    3.68e-05    4.11e-05
# Average_Travelling_Fans       0.0002   1.53e-05     11.019      0.000       0.000       0.000
# Cheapest_Season_T             0.0002      0.000      1.153      0.249      -0.000       0.000
# Home_League_Position         -0.0114      0.002     -7.486      0.000      -0.014      -0.008
# Away_League_Position         -0.0020      0.001     -1.516      0.130      -0.005       0.001
# Form_Home                     0.0051      0.003      1.788      0.074      -0.000       0.011
# Distance                     -0.0009      0.000     -5.550      0.000      -0.001      -0.001
# Lowest_Home_Ticket_Price      0.0074      0.003      2.768      0.006       0.002       0.013
# Lowest_Away_Ticket_Price     -0.0061      0.002     -2.629      0.009      -0.011      -0.002
# Highest_Home_Ticket_Price     0.0273      0.002     13.319      0.000       0.023       0.031
# match_month                  -0.0039      0.002     -1.662      0.097      -0.008       0.001
# HTeam                        -0.0004      0.001     -0.586      0.558      -0.002       0.001
# ATeam                        -0.0012      0.001     -1.814      0.070      -0.002    9.62e-05
# ==============================================================================
# Omnibus:                       31.535   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.107
# Skew:                          -0.170   Prob(JB):                     7.10e-05
# Kurtosis:                       2.452   Cond. No.                     5.77e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.98e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove HTeam variable
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Cheapest_Season_T','Home_League_Position','Away_League_Position',
       'Form_Home','Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     381.2
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:26   Log-Likelihood:                -204.53
# No. Observations:                1104   AIC:                             439.1
# Df Residuals:                    1089   BIC:                             514.2
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         7.6396      0.081     94.711      0.000       7.481       7.798
# Day_Type                     -0.0521      0.010     -5.074      0.000      -0.072      -0.032
# Hol_Type                      0.1624      0.036      4.475      0.000       0.091       0.234
# DayEve                       -0.0521      0.010     -5.074      0.000      -0.072      -0.032
# Capacity                   3.891e-05   1.11e-06     35.147      0.000    3.67e-05    4.11e-05
# Average_Travelling_Fans       0.0002   1.53e-05     11.028      0.000       0.000       0.000
# Cheapest_Season_T             0.0001      0.000      1.019      0.308      -0.000       0.000
# Home_League_Position         -0.0114      0.002     -7.486      0.000      -0.014      -0.008
# Away_League_Position         -0.0020      0.001     -1.504      0.133      -0.005       0.001
# Form_Home                     0.0050      0.003      1.777      0.076      -0.001       0.011
# Distance                     -0.0009      0.000     -5.527      0.000      -0.001      -0.001
# Lowest_Home_Ticket_Price      0.0071      0.003      2.711      0.007       0.002       0.012
# Lowest_Away_Ticket_Price     -0.0062      0.002     -2.689      0.007      -0.011      -0.002
# Highest_Home_Ticket_Price     0.0278      0.002     14.433      0.000       0.024       0.032
# match_month                  -0.0038      0.002     -1.654      0.098      -0.008       0.001
# ATeam                        -0.0012      0.001     -1.787      0.074      -0.002       0.000
# ==============================================================================
# Omnibus:                       30.186   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.623
# Skew:                          -0.170   Prob(JB):                     9.04e-05
# Kurtosis:                       2.462   Cond. No.                     3.07e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  7e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove Cheapest_Season_T variable
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Home_League_Position','Away_League_Position',
       'Form_Home','Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     410.5
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:27   Log-Likelihood:                -205.05
# No. Observations:                1104   AIC:                             438.1
# Df Residuals:                    1090   BIC:                             508.2
# Df Model:                          13
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         7.6500      0.080     95.611      0.000       7.493       7.807
# Day_Type                     -0.0518      0.010     -5.049      0.000      -0.072      -0.032
# Hol_Type                      0.1627      0.036      4.484      0.000       0.092       0.234
# DayEve                       -0.0518      0.010     -5.049      0.000      -0.072      -0.032
# Capacity                   3.898e-05   1.11e-06     35.275      0.000    3.68e-05    4.11e-05
# Average_Travelling_Fans       0.0002   1.53e-05     11.042      0.000       0.000       0.000
# Home_League_Position         -0.0113      0.002     -7.451      0.000      -0.014      -0.008
# Away_League_Position         -0.0020      0.001     -1.509      0.132      -0.005       0.001
# Form_Home                     0.0052      0.003      1.826      0.068      -0.000       0.011
# Distance                     -0.0009      0.000     -5.462      0.000      -0.001      -0.001
# Lowest_Home_Ticket_Price      0.0079      0.003      3.124      0.002       0.003       0.013
# Lowest_Away_Ticket_Price     -0.0062      0.002     -2.700      0.007      -0.011      -0.002
# Highest_Home_Ticket_Price     0.0282      0.002     14.983      0.000       0.024       0.032
# match_month                  -0.0038      0.002     -1.643      0.101      -0.008       0.001
# ATeam                        -0.0012      0.001     -1.796      0.073      -0.002       0.000
# ==============================================================================
# Omnibus:                       36.513   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.936
# Skew:                          -0.172   Prob(JB):                     2.84e-05
# Kurtosis:                       2.420   Cond. No.                     6.58e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.52e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove Away_League_Position variable
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Home_League_Position',
       'Form_Home','Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     444.0
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:27   Log-Likelihood:                -206.21
# No. Observations:                1104   AIC:                             438.4
# Df Residuals:                    1091   BIC:                             503.5
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         7.6303      0.079     96.606      0.000       7.475       7.785
# Day_Type                     -0.0518      0.010     -5.042      0.000      -0.072      -0.032
# Hol_Type                      0.1626      0.036      4.478      0.000       0.091       0.234
# DayEve                       -0.0518      0.010     -5.042      0.000      -0.072      -0.032
# Capacity                   3.899e-05   1.11e-06     35.260      0.000    3.68e-05    4.12e-05
# Average_Travelling_Fans       0.0002   1.49e-05     11.684      0.000       0.000       0.000
# Home_League_Position         -0.0114      0.002     -7.518      0.000      -0.014      -0.008
# Form_Home                     0.0047      0.003      1.672      0.095      -0.001       0.010
# Distance                     -0.0008      0.000     -5.351      0.000      -0.001      -0.001
# Lowest_Home_Ticket_Price      0.0078      0.003      3.103      0.002       0.003       0.013
# Lowest_Away_Ticket_Price     -0.0063      0.002     -2.708      0.007      -0.011      -0.002
# Highest_Home_Ticket_Price     0.0280      0.002     14.912      0.000       0.024       0.032
# match_month                  -0.0039      0.002     -1.676      0.094      -0.008       0.001
# ATeam                        -0.0012      0.001     -1.875      0.061      -0.002    5.66e-05
# ==============================================================================
# Omnibus:                       36.175   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.005
# Skew:                          -0.176   Prob(JB):                     2.75e-05
# Kurtosis:                       2.424   Cond. No.                     5.83e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.94e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove Form_Home variable
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Home_League_Position',
       'Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','match_month','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     483.3
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:28   Log-Likelihood:                -207.62
# No. Observations:                1104   AIC:                             439.2
# Df Residuals:                    1092   BIC:                             499.3
# Df Model:                          11
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         7.6661      0.076    100.761      0.000       7.517       7.815
# Day_Type                     -0.0519      0.010     -5.048      0.000      -0.072      -0.032
# Hol_Type                      0.1641      0.036      4.518      0.000       0.093       0.235
# DayEve                       -0.0519      0.010     -5.048      0.000      -0.072      -0.032
# Capacity                   3.911e-05    1.1e-06     35.425      0.000    3.69e-05    4.13e-05
# Average_Travelling_Fans       0.0002   1.49e-05     11.693      0.000       0.000       0.000
# Home_League_Position         -0.0126      0.001     -9.481      0.000      -0.015      -0.010
# Distance                     -0.0008      0.000     -5.376      0.000      -0.001      -0.001
# Lowest_Home_Ticket_Price      0.0080      0.003      3.143      0.002       0.003       0.013
# Lowest_Away_Ticket_Price     -0.0061      0.002     -2.619      0.009      -0.011      -0.002
# Highest_Home_Ticket_Price     0.0281      0.002     14.986      0.000       0.024       0.032
# match_month                  -0.0040      0.002     -1.717      0.086      -0.009       0.001
# ATeam                        -0.0012      0.001     -1.918      0.055      -0.003    2.87e-05
# ==============================================================================
# Omnibus:                       37.397   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.791
# Skew:                          -0.185   Prob(JB):                     1.85e-05
# Kurtosis:                       2.419   Cond. No.                     2.90e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.86e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove match_month variable
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Home_League_Position',
       'Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price','ATeam']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     530.4
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:29   Log-Likelihood:                -209.11
# No. Observations:                1104   AIC:                             440.2
# Df Residuals:                    1093   BIC:                             495.3
# Df Model:                          10
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         7.6374      0.074    102.820      0.000       7.492       7.783
# Day_Type                     -0.0508      0.010     -4.946      0.000      -0.071      -0.031
# Hol_Type                      0.1661      0.036      4.569      0.000       0.095       0.237
# DayEve                       -0.0508      0.010     -4.946      0.000      -0.071      -0.031
# Capacity                   3.907e-05    1.1e-06     35.367      0.000    3.69e-05    4.12e-05
# Average_Travelling_Fans       0.0002   1.49e-05     11.679      0.000       0.000       0.000
# Home_League_Position         -0.0125      0.001     -9.399      0.000      -0.015      -0.010
# Distance                     -0.0008      0.000     -5.244      0.000      -0.001      -0.001
# Lowest_Home_Ticket_Price      0.0078      0.003      3.100      0.002       0.003       0.013
# Lowest_Away_Ticket_Price     -0.0061      0.002     -2.615      0.009      -0.011      -0.002
# Highest_Home_Ticket_Price     0.0282      0.002     14.995      0.000       0.024       0.032
# ATeam                        -0.0012      0.001     -1.913      0.056      -0.003    3.17e-05
# ==============================================================================
# Omnibus:                       36.724   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.683
# Skew:                          -0.187   Prob(JB):                     1.96e-05
# Kurtosis:                       2.425   Cond. No.                     5.75e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  2e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# remove ATeam variable
x = df_sub[['Day_Type','Hol_Type','DayEve','Capacity','Average_Travelling_Fans','Home_League_Position',
       'Distance','Lowest_Home_Ticket_Price','Lowest_Away_Ticket_Price',
       'Highest_Home_Ticket_Price']]
x2 = sm.add_constant(x)
regressor_OLS = sm.OLS(endog = y, exog = x2).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Attendance   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     587.5
# Date:                Tue, 17 Jul 2018   Prob (F-statistic):               0.00
# Time:                        22:58:29   Log-Likelihood:                -210.95
# No. Observations:                1104   AIC:                             441.9
# Df Residuals:                    1094   BIC:                             492.0
# Df Model:                           9
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         7.6052      0.072    104.982      0.000       7.463       7.747
# Day_Type                     -0.0508      0.010     -4.946      0.000      -0.071      -0.031
# Hol_Type                      0.1659      0.036      4.559      0.000       0.095       0.237
# DayEve                       -0.0508      0.010     -4.946      0.000      -0.071      -0.031
# Capacity                   3.912e-05   1.11e-06     35.369      0.000    3.69e-05    4.13e-05
# Average_Travelling_Fans       0.0002   1.48e-05     12.012      0.000       0.000       0.000
# Home_League_Position         -0.0125      0.001     -9.356      0.000      -0.015      -0.010
# Distance                     -0.0008      0.000     -5.152      0.000      -0.001      -0.001
# Lowest_Home_Ticket_Price      0.0080      0.003      3.170      0.002       0.003       0.013
# Lowest_Away_Ticket_Price     -0.0065      0.002     -2.813      0.005      -0.011      -0.002
# Highest_Home_Ticket_Price     0.0282      0.002     14.994      0.000       0.025       0.032
# ==============================================================================
# Omnibus:                       37.117   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.537
# Skew:                          -0.181   Prob(JB):                     2.11e-05
# Kurtosis:                       2.420   Cond. No.                     6.55e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.54e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
fig = plt.figure(figsize=(20,24))
fig = sm.graphics.plot_partregress_grid(regressor_OLS, fig=fig)

# %%
# seaborn residual plot
sns.residplot(regressor_OLS.fittedvalues, y, lowess=True, line_kws={'color':'r', 'lw':1})
plt.title('Residual plot')
plt.xlabel('Predicted values')
plt.ylabel('Residuals');

# %%
fig, ax = plt.subplots(figsize=(24,16))
fig = sm.graphics.influence_plot(regressor_OLS, ax=ax, criterion="cooks")

# %%
# Q-Q plot for normality
figqq= sm.qqplot(regressor_OLS.resid, line='r')

# %% [markdown]
# ### This plot shows if residuals are normally distributed. Do residuals follow a straight line well or do they deviate severely? It’s good if residuals are lined well on the straight red line.
